# %% [markdown]
# # Notebook to Sub file Tex
#
# ## Objective
#
# This script is part of the hybrid chapter workflow, and to be used when you have created a ipython notebook and want to convert it to sub file tex where its preamble is removed, and instead added from the style file from our hybrid template. This sub file can be compiled separately and also becomes part of chapter, when included in the main tex file.
#
# ## Rules
# 1. Try to name the notebook without any spaces (use underscore instead).
# 2. Do not manually number the equations. Instead use align
#
# ## Remember
# 1. This only creates tex. You need to include it accordingly in main file. By default main tex has documentclass book, so recommended to add as a chapter.
#
# ## Input Parameters

# %%
source_file = "../chapters/24_HT_2_means.ipynb"  # file to be converted
tex_output_folder = "../chapters"
template_file = "ipy2tex_subfile_template.tplx"
temp_folder = "../tmp"
nbconvert_config_file = "nbconvert_config.py"


import ntpath
tex_file = ntpath.basename(source_file).split('.ipynb')[0] + ".tex"
tex_file_with_path_wo_ext = tex_output_folder + "/" + ntpath.basename(source_file).split('.ipynb')[0]

# %% [markdown]
# ## Steps
#
# 1. Create the template file. This is optional once the file is created. It is here just to show whats going on in template mostly.
# 2. Generate the tex file using the template file and ```nbconvert```.
#
# > A sample notebook is used to show the demo here
#
# ### Create Template

# %%
# %%writefile $template_file
#
# ((*- extends 'article.tplx' -*))
#
# % 1. CHANGE DOCUMENTCLASS TO STANDALONE
# ((* block docclass *))
# \documentclass[float=false,crop=false]{standalone}
# ((* endblock docclass *))
#
#
#
#
# % 2. REMOVE PREAMBLE AND REPLACE WITH STYLE FILE INCLUSION
# ((* block packages *))
# \usepackage{../myipy2tex}  % NOTE WE ARE ASSSUMING THE STYLE FILE TO BE ONE FOLDER ABOVE
# \usepackage{../myipy2tex_custom}  % YOUR FURTHER CUSTOM STYLES FOR IPYTHON TO LATEX
#
# % if you need to cross reference to any raw tex file from this resultant tex file you  need to refer them here..
# % it is not needed when you compile main.tex but make sure the labels are unique
# \ifstandalone
# \usepackage[numbers]{natbib}
# \bibliographystyle{abbrvnat}
# \usepackage{xr-hyper} % Needed for external references
#     \externaldocument{24_Hypothesis_Testing_Main}
# \title{Hypothesis Testing}
# \fi
#
#
# ((* endblock packages *))
# ((* block definitions *))
# ((* endblock definitions *))
# ((* block commands *))
# ((* endblock commands *))
#
# % Draw a figure using the graphicx package. Min size due to tikzmagic outputs being too shrinked.
# ((* macro draw_figure(filename) -*))
# ((* set filename = filename | posix_path *))
# ((*- block figure scoped -*))
#     \begin{center}
#     \adjustimage{max size={0.9\linewidth}{0.9\paperheight},min size={0.5\linewidth}{!}}{((( filename )))}
#     \end{center}
#     { \hspace*{\fill} \\}
# ((*- endblock figure -*))
# ((*- endmacro *))
#
#
# % 3. BELOW STUFF ARE JUST FOR CODE CELL CORRECTIONS TO GET LINES WRAPPED PROPERLY..
# %===============================================================================
# % Input
# %===============================================================================
#
# ((* block input scoped *))
#     ((*- if 'to_remove' in cell.metadata.get('tags', []) -*))  % remove input part of cells with tag to_remove
#     %((- if cell.metadata.hide_input -))
#     ((*- else -*))
#         ((( custom_add_prompt(cell.source | wrap_text(88) | highlight_code(strip_verbatim=True), cell, 'In', 'incolor') )))
#     ((*- endif -*))
# ((* endblock input *))
#
# %===============================================================================
# % Output
# %===============================================================================
#
# % Display stream ouput with coloring
# ((* block stream *))
#     \begin{Verbatim}[commandchars=\\\{\},fontsize=\footnotesize]
# ((( output.text | wrap_text(86) | escape_latex | ansi2latex )))
#     \end{Verbatim}
# ((* endblock stream *))
#
# %==============================================================================
# % Define macro custom_add_prompt() (derived from add_prompt() macro in style_ipython.tplx)
# %==============================================================================
#
# ((* macro custom_add_prompt(text, cell, prompt, prompt_color) -*))
#     ((*- if cell.execution_count is defined -*))
#     ((*- set execution_count = "" ~ (cell.execution_count | replace(None, " ")) -*))
#     ((*- else -*))
#     ((*- set execution_count = " " -*))
#     ((*- endif -*))
#     ((*- set indention =  " " * (execution_count | length + 7) -*))
# \begin{((( prompt ~ 'Verbatim')))}[commandchars=\\\{\},fontsize=\scriptsize]
# ((( text | add_prompts(first='{\color{' ~ prompt_color ~ '}' ~ prompt ~ '[{\\color{' ~ prompt_color ~ '}' ~ execution_count ~ '}]:} ', cont=indention) )))
# \end{((( prompt ~ 'Verbatim')))}
# ((*- endmacro *))
# Out:
# Overwriting ipy2tex_subfile_template.tplx

# %% [markdown]
# ### Create Tex
#
# By default, the attachments in markdown cells are not exported, so we will have a small config file to force that as well

# %%
# %%writefile $nbconvert_config_file
#
# c.NbConvertApp.export_format = 'latex'
# c.LatexExporter.preprocessors = [
#     'extract_attachments.ExtractAttachmentsPreprocessor'  # custom preprocessor from extract_attachments.py
#     ]
# Out:
# Overwriting nbconvert_config.py

# %%
# !jupyter nbconvert --log-level='DEBUG' --template "$template_file" "$source_file" --output-dir="$tex_output_folder" --config "$nbconvert_config_file"
# Out:
# [NbConvertApp] Searching ['D:\\Parthiban\\Business\\HigherStudies\\Online Courses\\Udacity\\Intro to Statistics\\26_Hypothesis_Test\\tools', 'C:\\Users\\parthi2929\\.jupyter', 'C:\\Users\\parthi2929\\Anaconda3\\etc\\jupyter', 'C:\\ProgramData\\jupyter'] for config files
# [NbConvertApp] Looking for jupyter_config in C:\ProgramData\jupyter
# [NbConvertApp] Looking for jupyter_config in C:\Users\parthi2929\Anaconda3\etc\jupyter
# [NbConvertApp] Looking for jupyter_config in C:\Users\parthi2929\.jupyter
# [NbConvertApp] Looking for jupyter_config in D:\Parthiban\Business\HigherStudies\Online Courses\Udacity\Intro to Statistics\26_Hypothesis_Test\tools
# [NbConvertApp] Looking for nbconvert_config in D:\Parthiban\Business\HigherStudies\Online Courses\Udacity\Intro to Statistics\26_Hypothesis_Test\tools
# [NbConvertApp] Loaded config file: D:\Parthiban\Business\HigherStudies\Online Courses\Udacity\Intro to Statistics\26_Hypothesis_Test\tools\nbconvert_config.py
# [NbConvertApp] Converting notebook ../chapters/24_HT_2_means.ipynb to latex
# [NbConvertApp] Notebook name is '24_HT_2_means'
# [NbConvertApp] Applying preprocessor: TagRemovePreprocessor
# [NbConvertApp] Applying preprocessor: RegexRemovePreprocessor
# [NbConvertApp] Applying preprocessor: coalesce_streams
# [NbConvertApp] Applying preprocessor: SVG2PDFPreprocessor
# [NbConvertApp] Applying preprocessor: LatexPreprocessor
# [NbConvertApp] Applying preprocessor: HighlightMagicsPreprocessor
# [NbConvertApp] Applying preprocessor: ExtractOutputPreprocessor
# [NbConvertApp] Applying preprocessor: ExtractAttachmentsPreprocessor
# [NbConvertApp] Attempting to load template ipy2tex_subfile_template.tplx
# [NbConvertApp]     template_path: .
# [NbConvertApp] Support files will be in 24_HT_2_means_files\
# [NbConvertApp] Making directory ../chapters\24_HT_2_means_files
# [NbConvertApp] Writing 25538 bytes to support file ../chapters\24_HT_2_means_files\24_HT_2_means_3_0.png
# [NbConvertApp] Making directory ../chapters\24_HT_2_means_files
# [NbConvertApp] Writing 17435 bytes to support file ../chapters\24_HT_2_means_files\24_HT_2_means_5_0.png
# [NbConvertApp] Making directory ../chapters\24_HT_2_means_files
# [NbConvertApp] Writing 16170 bytes to support file ../chapters\24_HT_2_means_files\24_HT_2_means_10_0.png
# [NbConvertApp] Making directory ../chapters\24_HT_2_means_files
# [NbConvertApp] Writing 22599 bytes to support file ../chapters\24_HT_2_means_files\24_HT_2_means_19_0.png
# [NbConvertApp] Making directory ../chapters\24_HT_2_means_files
# [NbConvertApp] Writing 15599 bytes to support file ../chapters\24_HT_2_means_files\24_HT_2_means_25_0.png
# [NbConvertApp] Making directory ../chapters\24_HT_2_means_files
# [NbConvertApp] Writing 15155 bytes to support file ../chapters\24_HT_2_means_files\24_HT_2_means_31_0.png
# [NbConvertApp] Making directory ../chapters\24_HT_2_means_files
# [NbConvertApp] Writing 60834 bytes to support file ../chapters\24_HT_2_means_files\24_HT_2_means_36_0.png
# [NbConvertApp] Making directory ../chapters\24_HT_2_means_files
# [NbConvertApp] Writing 33554 bytes to support file ../chapters\24_HT_2_means_files\24_HT_2_means_44_0.png
# [NbConvertApp] Making directory ../chapters\24_HT_2_means_files
# [NbConvertApp] Writing 30287 bytes to support file ../chapters\24_HT_2_means_files\24_HT_2_means_46_0.png
# [NbConvertApp] Making directory ../chapters\24_HT_2_means_files
# [NbConvertApp] Writing 33236 bytes to support file ../chapters\24_HT_2_means_files\24_HT_2_means_48_0.png
# [NbConvertApp] Making directory ../chapters\24_HT_2_means_files
# [NbConvertApp] Writing 30785 bytes to support file ../chapters\24_HT_2_means_files\24_HT_2_means_51_0.png
# [NbConvertApp] Writing 23854 bytes to ../chapters\24_HT_2_means.tex

# %% [markdown]
# ## Test pdf
#
# This pdf is just intermediary for us to test if output is ok (should work as we have made it 'standalone' as well). This shall also go to same chapters folder for us to refer later easily.

# %%
#!pdflatex.exe -synctex=1 -interaction=nonstopmode -output-directory 1 "$tex_file"
from subprocess import Popen, PIPE
process = Popen(['pdflatex.exe', '-synctex=1', '-interaction=nonstopmode', '-output-directory', tex_output_folder, '-aux-directory', temp_folder , tex_file], shell=True, stdout=PIPE)

for line in process.stdout:
    print(line.decode().strip())
# Out:
# This is pdfTeX, Version 3.14159265-2.6-1.40.19 (MiKTeX 2.9.6800 64-bit)
# entering extended mode
#
# ("D:/Parthiban/Business/HigherStudies/Online Courses/Udacity/Intro to Statistic
# s/26_Hypothesis_Test/chapters/24_HT_2_means.tex"
# LaTeX2e <2018-04-01> patch level 5
# ("C:\Program Files\MiKTeX 2.9\tex\latex\standalone\standalone.cls"
# Document Class: standalone 2018/03/26 v1.3a Class to compile TeX sub-files stan
# dalone
# ("C:\Program Files\MiKTeX 2.9\tex\latex\tools\shellesc.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\generic\oberdiek\ifluatex.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\generic\oberdiek\ifpdf.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\generic\ifxetex\ifxetex.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\xkeyval\xkeyval.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\generic\xkeyval\xkeyval.tex"
# ("C:\Program Files\MiKTeX 2.9\tex\generic\xkeyval\xkvutils.tex"
# ("C:\Program Files\MiKTeX 2.9\tex\generic\xkeyval\keyval.tex"))))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\standalone\standalone.cfg")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\base\article.cls"
# Document Class: article 2014/09/29 v1.4h Standard LaTeX document class
# ("C:\Program Files\MiKTeX 2.9\tex\latex\base\size10.clo"))) (../myipy2tex.sty
#
# LaTeX Warning: You have requested package `../myipy2tex',
# but the package provides `myipy2tex'.
#
# ("C:\Program Files\MiKTeX 2.9\tex\latex\tcolorbox\tcolorbox.sty"
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\latex\pgf\basiclayer\pgf.st
# y
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\latex\pgf\utilities\pgfrcs.
# sty
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\utilities\pgfut
# il-common.tex
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\utilities\pgfut
# il-common-lists.tex))
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\utilities\pgfut
# il-latex.def
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\latex\ms\everyshi.sty))
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\utilities\pgfrc
# s.code.tex))
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\latex\pgf\basiclayer\pgfcor
# e.sty ("C:\Program Files\MiKTeX 2.9\tex\latex\graphics\graphicx.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\graphics\graphics.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\graphics\trig.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\graphics-cfg\graphics.cfg")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\graphics-def\pdftex.def")))
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\latex\pgf\systemlayer\pgfsy
# s.sty
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\systemlayer\pgf
# sys.code.tex
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\utilities\pgfke
# ys.code.tex
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\utilities\pgfke
# ysfiltered.code.tex))
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\systemlayer\pgf
# .cfg)
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\systemlayer\pgf
# sys-pdftex.def
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\systemlayer\pgf
# sys-common-pdf.def)))
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\systemlayer\pgf
# syssoftpath.code.tex)
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\systemlayer\pgf
# sysprotocol.code.tex))
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\latex\xcolor\xcolor.sty
# ("C:\Program Files\MiKTeX 2.9\tex\latex\graphics-cfg\color.cfg"))
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\basiclayer\pgfc
# ore.code.tex
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\math\pgfmath.co
# de.tex
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\math\pgfmathcal
# c.code.tex
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\math\pgfmathuti
# l.code.tex)
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\math\pgfmathpar
# ser.code.tex)
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\math\pgfmathfun
# ctions.code.tex
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\math\pgfmathfun
# ctions.basic.code.tex)
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\math\pgfmathfun
# ctions.trigonometric.code.tex)
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\math\pgfmathfun
# ctions.random.code.tex)
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\math\pgfmathfun
# ctions.comparison.code.tex)
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\math\pgfmathfun
# ctions.base.code.tex)
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\math\pgfmathfun
# ctions.round.code.tex)
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\math\pgfmathfun
# ctions.misc.code.tex)
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\math\pgfmathfun
# ctions.integerarithmetics.code.tex)))
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\math\pgfmathflo
# at.code.tex))
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\basiclayer\pgfc
# orepoints.code.tex)
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\basiclayer\pgfc
# orepathconstruct.code.tex)
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\basiclayer\pgfc
# orepathusage.code.tex)
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\basiclayer\pgfc
# orescopes.code.tex)
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\basiclayer\pgfc
# oregraphicstate.code.tex)
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\basiclayer\pgfc
# oretransformations.code.tex)
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\basiclayer\pgfc
# orequick.code.tex)
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\basiclayer\pgfc
# oreobjects.code.tex)
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\basiclayer\pgfc
# orepathprocessing.code.tex)
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\basiclayer\pgfc
# orearrows.code.tex)
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\basiclayer\pgfc
# oreshade.code.tex)
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\basiclayer\pgfc
# oreimage.code.tex
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\basiclayer\pgfc
# oreexternal.code.tex))
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\basiclayer\pgfc
# orelayers.code.tex)
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\basiclayer\pgfc
# oretransparency.code.tex)
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\basiclayer\pgfc
# orepatterns.code.tex)))
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\modules\pgfmodu
# leshapes.code.tex)
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\modules\pgfmodu
# leplot.code.tex)
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\latex\pgf\compatibility\pgf
# comp-version-0-65.sty)
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\latex\pgf\compatibility\pgf
# comp-version-1-18.sty))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\tools\verbatim.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\environ\environ.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\trimspaces\trimspaces.sty"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\etoolbox\etoolbox.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\tcolorbox\tcbbreakable.code.tex"
# Library (tcolorbox): 'tcbbreakable.code.tex' version '4.14'
# )) ("C:\Program Files\MiKTeX 2.9\tex\latex\needspace\needspace.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\caption\caption.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\caption\caption3.sty"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\adjustbox\adjustbox.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\adjustbox\adjcalc.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\adjustbox\trimclip.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\collectbox\collectbox.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\adjustbox\tc-pdftex.def"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\ifoddpage\ifoddpage.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\varwidth\varwidth.sty"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\tools\enumerate.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\geometry\geometry.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\generic\oberdiek\ifvtex.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\geometry\geometry.cfg"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\amsmath\amsmath.sty"
# For additional information on amsmath, use the `?' option.
# ("C:\Program Files\MiKTeX 2.9\tex\latex\amsmath\amstext.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\amsmath\amsgen.sty"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\amsmath\amsbsy.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\amsmath\amsopn.sty"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\amsfonts\amssymb.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\amsfonts\amsfonts.sty"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\base\textcomp.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\base\ts1enc.def"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\base\ts1enc.dfu")))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\upquote\upquote.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\eurosym\eurosym.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\ucs\ucs.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\ucs\uni-global.def"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\base\inputenc.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\ucs\utf8x.def"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\fancyvrb\fancyvrb.sty"
# Style option: `fancyvrb' v2.7a, with DG/SPQR fixes, and firstline=lastline fix
# <2008/02/07> (tvz)) ("C:\Program Files\MiKTeX 2.9\tex\latex\oberdiek\grffile.st
# y" ("C:\Program Files\MiKTeX 2.9\tex\latex\oberdiek\kvoptions.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\generic\oberdiek\ltxcmds.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\generic\oberdiek\kvsetkeys.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\generic\oberdiek\infwarerr.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\generic\oberdiek\etexcmds.sty")))
# ("C:\Program Files\MiKTeX 2.9\tex\generic\oberdiek\pdftexcmds.sty"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\hyperref\hyperref.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\generic\oberdiek\hobsub-hyperref.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\generic\oberdiek\hobsub-generic.sty"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\oberdiek\auxhook.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\hyperref\pd1enc.def")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\00miktex\hyperref.cfg")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\url\url.sty"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\hyperref\hpdftex.def"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\oberdiek\rerunfilecheck.sty"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\tools\longtable.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\booktabs\booktabs.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\enumitem\enumitem.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\ulem\ulem.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\base\fontenc.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\base\ot1enc.def")))
# (../myipy2tex_custom.sty
#
# LaTeX Warning: You have requested package `../myipy2tex_custom',
# but the package provides `myrawtex'.
#
# ("C:\Program Files\MiKTeX 2.9\tex\latex\tools\indentfirst.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\tools\tabularx.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\tools\array.sty"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\colortbl\colortbl.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\tcolorbox\tcbskins.code.tex"
# Library (tcolorbox): 'tcbskins.code.tex' version '4.14'
#
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\latex\pgf\frontendlayer\tik
# z.sty
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\latex\pgf\utilities\pgffor.
# sty
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\latex\pgf\utilities\pgfkeys
# .sty
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\utilities\pgfke
# ys.code.tex))
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\latex\pgf\math\pgfmath.sty
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\math\pgfmath.co
# de.tex))
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\utilities\pgffo
# r.code.tex
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\math\pgfmath.co
# de.tex)))
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\frontendlayer\t
# ikz\tikz.code.tex
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\libraries\pgfli
# braryplothandlers.code.tex)
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\modules\pgfmodu
# lematrix.code.tex)
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\frontendlayer\t
# ikz\libraries\tikzlibrarytopaths.code.tex)))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\tcolorbox\tcbskinsjigsaw.code.tex"
# Library (tcolorbox): 'tcbskinsjigsaw.code.tex' version '4.14'
# ))
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\frontendlayer\t
# ikz\libraries\tikzlibraryshapes.geometric.code.tex
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\libraries\shape
# s\pgflibraryshapes.geometric.code.tex))
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\frontendlayer\t
# ikz\libraries\tikzlibraryarrows.code.tex
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\generic\pgf\libraries\pgfli
# braryarrows.code.tex)))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\natbib\natbib.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\hyperref\xr-hyper.sty"
#
# Package xr-hyper Warning: Load package `hyperref' after `xr-hyper'.
#
# )
#
# Package xr Warning:
# No file 24_Hypothesis_Testing_Main.aux
# LABELS NOT IMPORTED.
# on input line 27.
#
#
# ("D:\Parthiban\Business\HigherStudies\Online Courses\Udacity\Intro to Statistic
# s\26_Hypothesis_Test\tmp\24_HT_2_means.aux")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\base\ts1cmr.fd")
# ABD: EveryShipout initializing macros
# (C:\Users\parthi2929\AppData\Roaming\MiKTeX\2.9\tex\context\base\supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# ) ("C:\Program Files\MiKTeX 2.9\tex\latex\oberdiek\epstopdf-base.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\oberdiek\grfext.sty"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\caption\ltcaption.sty")
# *geometry* driver: auto-detecting
# *geometry* detected driver: pdftex
#
# Package geometry Warning: The marginal notes overrun the paper.
# Add 3.73001pt and more to the right margin.
#
# *geometry* verbose mode - [ preamble ] result:
# * driver: pdftex
# * paper: <default>
# * layout: <same size as paper>
# * layoutoffset:(h,v)=(0.0pt,0.0pt)
# * modes:
# * h-part:(L,W,R)=(72.26999pt, 469.75502pt, 72.26999pt)
# * v-part:(T,H,B)=(72.26999pt, 650.43001pt, 72.26999pt)
# * \paperwidth=614.295pt
# * \paperheight=794.96999pt
# * \textwidth=469.75502pt
# * \textheight=650.43001pt
# * \oddsidemargin=0.0pt
# * \evensidemargin=0.0pt
# * \topmargin=-37.0pt
# * \headheight=12.0pt
# * \headsep=25.0pt
# * \topskip=10.0pt
# * \footskip=30.0pt
# * \marginparwidth=65.0pt
# * \marginparsep=11.0pt
# * \columnsep=10.0pt
# * \skip\footins=9.0pt plus 4.0pt minus 2.0pt
# * \hoffset=0.0pt
# * \voffset=0.0pt
# * \mag=1000
# * \@twocolumnfalse
# * \@twosidefalse
# * \@mparswitchfalse
# * \@reversemarginfalse
# * (1in=72.27pt=25.4mm, 1cm=28.453pt)
#
# ("C:\Program Files\MiKTeX 2.9\tex\latex\ucs\ucsencs.def")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\hyperref\nameref.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\generic\oberdiek\gettitlestring.sty"))
# ("D:\Parthiban\Business\HigherStudies\Online Courses\Udacity\Intro to Statistic
# s\26_Hypothesis_Test\tmp\24_HT_2_means.out")
# ("D:\Parthiban\Business\HigherStudies\Online Courses\Udacity\Intro to Statistic
# s\26_Hypothesis_Test\tmp\24_HT_2_means.out")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\amsfonts\umsa.fd")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\amsfonts\umsb.fd")
# Underfull \hbox (badness 10000) in paragraph at lines 77--78
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 101--102
#
# [1{C:/Users/parthi2929/AppData/Local/MiKTeX/2.9/pdftex/config/pdftex.map} <D:/P
# arthiban/Business/HigherStudies/Online Courses/Udacity/Intro to Statistics/26_H
# ypothesis_Test/chapters/24_HT_2_means_files/24_HT_2_means_3_0.png> <D:/Parthiba
# n/Business/HigherStudies/Online Courses/Udacity/Intro to Statistics/26_Hypothes
# is_Test/chapters/24_HT_2_means_files/24_HT_2_means_5_0.png>]
# Underfull \hbox (badness 10000) in paragraph at lines 131--132
#
#
# Overfull \hbox (5.28595pt too wide) in paragraph at lines 155--156
# \OML/cmm/m/it/10 S[][]$
# [2pdfTeX warning (ext4): destination with the same identifier (name{equation.1.
# 1}) has been already used, duplicate ignored
#
# \@EveryShipout@Output ...@Org@Shipout \box \@cclv
#
# l.167     \section
# {Examples}\label{examples} <D:/Parthiban/Business/HigherStudi
# es/Online Courses/Udacity/Intro to Statistics/26_Hypothesis_Test/chapters/24_HT
# _2_means_files/24_HT_2_means_10_0.png>] [3]
# Underfull \hbox (badness 10000) in paragraph at lines 207--208
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 260--261
#
# [4 <D:/Parthiban/Business/HigherStudies/Online Courses/Udacity/Intro to Statist
# ics/26_Hypothesis_Test/chapters/24_HT_2_means_files/24_HT_2_means_19_0.png> <D:
# /Parthiban/Business/HigherStudies/Online Courses/Udacity/Intro to Statistics/26
# _Hypothesis_Test/chapters/24_HT_2_means_files/24_HT_2_means_25_0.png>]
# Underfull \hbox (badness 10000) in paragraph at lines 298--299
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 310--310
# [][][]\OT1/cmr/m/n/8 https://www.khanacademy.org/math/ap-statistics/two-sample-
# inference/two-sample-t-test-means/v/two-sample-t-test-
# [5 <D:/Parthiban/Business/HigherStudies/Online Courses/Udacity/Intro to Statist
# ics/26_Hypothesis_Test/chapters/24_HT_2_means_files/24_HT_2_means_31_0.png>]
# Underfull \hbox (badness 10000) in paragraph at lines 335--336
#
# [6 <D:/Parthiban/Business/HigherStudies/Online Courses/Udacity/Intro to Statist
# ics/26_Hypothesis_Test/chapters/24_HT_2_means_files/24_HT_2_means_36_0.png>]
# Underfull \hbox (badness 10000) in paragraph at lines 395--396
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 407--408
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 424--425
#
# pdfTeX warning (ext4): destination with the same identifier (name{equation.3.3}
# ) has been already used, duplicate ignored
# <to be read again>
# \relax
# l.426     \begin{equation}
# pdfTeX warning (ext4): destination with the same iden
# tifier (name{equation.3.3}) has been already used, duplicate ignored
# <to be read again>
# \relax
# l.426     \begin{equation}
# pdfTeX warning (ext4): destination with the same iden
# tifier (name{equation.3.3}) has been already used, duplicate ignored
# <to be read again>
# \relax
# l.426     \begin{equation}
# pdfTeX warning (ext4): destination with the same iden
# tifier (name{equation.3.3}) has been already used, duplicate ignored
# <to be read again>
# \relax
# l.426     \begin{equation}
# [7 <D:/Parthiban/Business/HigherStudies/Online Cours
# es/Udacity/Intro to Statistics/26_Hypothesis_Test/chapters/24_HT_2_means_files/
# 24_HT_2_means_44_0.png> <D:/Parthiban/Business/HigherStudies/Online Courses/Uda
# city/Intro to Statistics/26_Hypothesis_Test/chapters/24_HT_2_means_files/24_HT_
# 2_means_46_0.png> <D:/Parthiban/Business/HigherStudies/Online Courses/Udacity/I
# ntro to Statistics/26_Hypothesis_Test/chapters/24_HT_2_means_files/24_HT_2_mean
# s_48_0.png>] ("C:\Program Files\MiKTeX 2.9\tex\latex\ucs\uni-34.def")
# Underfull \hbox (badness 10000) in paragraph at lines 453--454
#
# [8 <D:/Parthiban/Business/HigherStudies/Online Courses/Udacity/Intro to Statist
# ics/26_Hypothesis_Test/chapters/24_HT_2_means_files/24_HT_2_means_51_0.png>]
# ("D:\Parthiban\Business\HigherStudies\Online Courses\Udacity\Intro to Statistic
# s\26_Hypothesis_Test\tmp\24_HT_2_means.aux") )
# (see the transcript file for additional information)<C:/Program Files/MiKTeX 2.
# 9/fonts/type1/public/amsfonts/cm/cmbx10.pfb><C:/Program Files/MiKTeX 2.9/fonts/
# type1/public/amsfonts/cm/cmbx12.pfb><C:/Program Files/MiKTeX 2.9/fonts/type1/pu
# blic/amsfonts/cm/cmex10.pfb><C:/Program Files/MiKTeX 2.9/fonts/type1/public/ams
# fonts/cm/cmitt10.pfb><C:/Program Files/MiKTeX 2.9/fonts/type1/public/amsfonts/c
# m/cmmi10.pfb><C:/Program Files/MiKTeX 2.9/fonts/type1/public/amsfonts/cm/cmmi12
# .pfb><C:/Program Files/MiKTeX 2.9/fonts/type1/public/amsfonts/cm/cmmi5.pfb><C:/
# Program Files/MiKTeX 2.9/fonts/type1/public/amsfonts/cm/cmmi7.pfb><C:/Program F
# iles/MiKTeX 2.9/fonts/type1/public/amsfonts/cm/cmr10.pfb><C:/Program Files/MiKT
# eX 2.9/fonts/type1/public/amsfonts/cm/cmr12.pfb><C:/Program Files/MiKTeX 2.9/fo
# nts/type1/public/amsfonts/cm/cmr17.pfb><C:/Program Files/MiKTeX 2.9/fonts/type1
# /public/amsfonts/cm/cmr5.pfb><C:/Program Files/MiKTeX 2.9/fonts/type1/public/am
# sfonts/cm/cmr6.pfb><C:/Program Files/MiKTeX 2.9/fonts/type1/public/amsfonts/cm/
# cmr7.pfb><C:/Program Files/MiKTeX 2.9/fonts/type1/public/amsfonts/cm/cmr8.pfb><
# C:/Program Files/MiKTeX 2.9/fonts/type1/public/amsfonts/cm/cmsy10.pfb><C:/Progr
# am Files/MiKTeX 2.9/fonts/type1/public/amsfonts/cm/cmsy5.pfb><C:/Program Files/
# MiKTeX 2.9/fonts/type1/public/amsfonts/cm/cmsy7.pfb><C:/Program Files/MiKTeX 2.
# 9/fonts/type1/public/amsfonts/cm/cmti10.pfb><C:/Program Files/MiKTeX 2.9/fonts/
# type1/public/amsfonts/cm/cmtt8.pfb>
# Output written on "D:\Parthiban\Business\HigherStudies\Online Courses\Udacity\I
# ntro to Statistics\26_Hypothesis_Test\chapters\24_HT_2_means.pdf" (8 pages, 446
# 769 bytes).
# SyncTeX written on D:\Parthiban\Business\HigherStudies\Online Courses\Udacity\Intro to Statistics\26_Hypothesis_Test\chapters\24_HT_2_means.synctex.gz.
# Transcript written on "D:\Parthiban\Business\HigherStudies\Online Courses\Udaci
# ty\Intro to Statistics\26_Hypothesis_Test\tmp\24_HT_2_means.log".

# %% [markdown]
# ### View pdf

# %%
from IPython.display import HTML
def PDF(url):
    return HTML('<iframe src=%s width=700 height=350></iframe>' % url)

pdf_file = "\"" + tex_output_folder + '/' + ntpath.basename(source_file).split('.ipynb')[0] + '.pdf' + "\""
print('location of test pdf: ' + pdf_file)
HTML('<iframe src={0} width=100% height=600></iframe>'.format(pdf_file))
# Out:
# location of test pdf: "../chapters/24_HT_2_means.pdf"
# <iframe src="../chapters/24_HT_2_means.pdf" width=100% height=600></iframe>
